# %%
import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd()).parent.parent))

# %%
import merlin
from merlin.charms.models.lightgbm import LightGBMOptunaCV
from merlin.tools import load_callback

from merlin.utils import seed_everything
seed_everything(42)
# Out:
# Global seed set to 42
# 42

# %% [markdown]
# # 数据准备

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb 
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
X, y = fetch_openml("Bank_marketing_data_set_UCI", 
                    version=1, as_frame=True, return_X_y=True,parser='auto')
dfdata = X.join(y)
del X, y


cat_cols = ['job', 'marital', 'education', 'default', 'housing',
       'loan', 'contact', 'day', 'month', 'campaign',
       'previous', 'poutcome']

num_cols = ['age', 'balance', 'duration', 'pdays']
target_col="y"

dfdata.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#将target列转换为数值
encoder = OrdinalEncoder(handle_unknown="use_encoded_value", encoded_missing_value=np.nan, unknown_value=np.nan)
dfdata[target_col] = encoder.fit_transform(dfdata[[target_col]])


for col in  cat_cols:
    encoder = OrdinalEncoder(handle_unknown="use_encoded_value", encoded_missing_value=np.nan, unknown_value=np.nan)
    dfdata[col] = encoder.fit_transform(dfdata[col].values.reshape(-1,1))[:,0]


dftmp, dftest = train_test_split(dfdata, stratify=dfdata["y"], test_size=0.2, random_state=42)
dftrain, dfval = train_test_split(dftmp, stratify=dftmp["y"], test_size=0.2, random_state=42)


ds_train = lgb.Dataset(dftrain[num_cols+cat_cols], label=dftrain[target_col],categorical_feature=cat_cols)
ds_val = lgb.Dataset(dfval[num_cols+cat_cols],label=dfval[target_col],categorical_feature=cat_cols)
ds_test = lgb.Dataset(dftest[num_cols+cat_cols], label=dftest[target_col],categorical_feature=cat_cols)

# %% [markdown]
# # 模型和回调函数定义

# %%
params = {
    'n_estimators': {'type': 'int', 'low': 100, 'high': 1000},
    'learning_rate': {'type': 'float', 'low': 0.01, 'high': 0.3, 'log': False},
    'num_leaves': {'type': 'int', 'low': 20, 'high': 300},
    'max_depth': {'type': 'int', 'low': 3, 'high': 12},
    'min_child_samples': {'type': 'int', 'low': 5, 'high': 100},
    'subsample': {'type': 'float', 'low': 0.5, 'high': 1.0, 'log': False},
    'colsample_bytree': {'type': 'float', 'low': 0.5, 'high': 1.0, 'log': False},
    'reg_alpha': {'type': 'float', 'low': 1e-8, 'high': 10.0, 'log': True},
    'reg_lambda': {'type': 'float', 'low': 1e-8, 'high': 10.0, 'log': True},
}

model = LightGBMOptunaCV(
    n_trials=100, param_space=params, cv_folds=5, enable_cv=True
)

# %%
callback = load_callback("lightgbm")
callback
# Out:
# merlin.tools.callbacks.VlogCallback

# %% [markdown]
# # 模型训练

# %%
#设计模型的参数
params = {
    'n_estimators':1000,
    'boosting_type': 'gbdt',
    'objective':'binary',
    'metric': 'auc', 
    'learning_rate': 0.01,
    'verbose': 3,
    'early_stopping_round':100
}

# %%
lgb.record_evaluation(result)

# %%
vlog_cb = callback(params['n_estimators'], monitor_metric = 'valid_0_auc', monitor_mode = 'max')
vlog_cb.vlog.log_start()
result = {}

model = lgb.train(params, ds_train, 
        valid_sets=[ds_val], 
        # valid_names=['val'],
        callbacks = [lgb.record_evaluation(result), vlog_cb]
        )

vlog_cb.vlog.log_end()
# Out:
# <style>
#     /* background: */
#     progress::-webkit-progress-bar {background-color: #CDCDCD; width: 100%;}
#     progress {background-color: #CDCDCD;}
#
#     /* value: */
#     progress::-webkit-progress-value {background-color: #00BFFF  !important;}
#     progress::-moz-progress-bar {background-color: #00BFFF  !important;}
#     progress {color: #00BFFF ;}
#
#     /* optional */
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #000000;
#     }
# </style>
#     <div>
#       <progress value='200' class='' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [200/1000] [00:13<00:55]
#       <br>
#
#     </div>
# [LightGBM] [Info] Number of positive: 3385, number of negative: 25549
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.821070
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.393268
# [LightGBM] [Debug] init for col-wise cost 0.000839 seconds, init for row-wise cost 0.001184 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001223 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 981
# [LightGBM] [Info] Number of data points in the train set: 28934, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116990 -> initscore=-2.021244
# [LightGBM] [Info] Start training from score -2.021244
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.8903276644595141), True)
# Training until validation scores don't improve for 100 rounds
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.8903276644595141), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ('valid_0', 'auc', np.float64(0.8907647280435687), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# ('valid_0', 'auc', np.float64(0.891201699107813), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 13
# ('valid_0', 'auc', np.float64(0.8914631600918389), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ('valid_0', 'auc', np.float64(0.8916921466224348), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ('valid_0', 'auc', np.float64(0.8987685243164266), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9021848183132972), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9034318928368943), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9042943625089004), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9055493012163764), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.905792535797765), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9135804833530956), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9142197952425574), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9142414448781773), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9168541118024192), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9172251162418897), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9170625589351192), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9173387305689894), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9173420612821618), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9176196207131871), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9178870029650749), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9179077274025914), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9181699285451), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9185552735551736), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9187010847762723), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9195602237351062), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9200620511864), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9204218607288193), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9215965847607289), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9221884339874854), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9225130860019748), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9227210705356231), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.922873173103825), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9231899609344353), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9238421330775346), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9233823096201359), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9235741957067848), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.924163546898662), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9242564367882451), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9243189801800361), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9243387794194493), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.924451838627687), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ('valid_0', 'auc', np.float64(0.9245241891193743), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9241617890222654), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9242721651560032), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9243307301959496), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9243448857269319), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.924288633682244), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9242983482623299), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9243558955843625), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9243962342216715), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9243852243642409), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9256333166057517), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9259649076060166), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9261455062758037), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9261208960062529), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9265057784172747), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9268574462163839), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9270646905915495), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9271665549027358), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9273074625738863), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9274109922416588), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9275671656815158), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9277708943038884), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9279192960796766), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9280749144006715), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9281901940843573), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9283321194734216), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9284011392519367), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9285055015980022), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9285598107266728), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9286554762105662), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9287715885725452), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9287761220432519), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9288671615366282), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9289532974800564), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9289961341522447), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9290302739622608), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9290691322826043), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9289947463550896), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9291476816015846), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9291151146283442), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9291202957377234), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.929123441411275), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9290771815061041), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9290917996361381), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9290586775440357), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9290452621715362), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9291068803652238), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9290794019815523), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9290558094299152), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9290181538671061), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.929042764136657), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9291003114586895), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9291244591291887), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9291445359280329), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9292750813804251), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.929313477101717), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9294652095906776), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.929485378909332), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9295046230298831), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9295027726336763), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9294961112073317), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.92957142233295), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9295741979272601), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.929560875074571), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9296691232526708), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.929732499322755), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9298268695293036), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9298555506705096), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9299175389434385), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9299464051242652), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9299454799261618), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9300000666142635), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9303497914973554), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9304785790733512), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.930552965000866), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9306643588525175), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9307095085199643), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9307715893127037), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9308678099154591), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9309282253516122), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.930964678156887), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9309870679509896), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9310257412317126), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9310440601541602), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9311142826902097), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9311720150518629), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9312192001551373), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9312506568906534), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9312823911856006), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9313500231669605), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9313618657026843), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9314429130565437), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.931450314641371), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9315285864009202), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9315437596498162), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9316061180019866), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9315811376531943), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.931661999967433), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9316910511878803), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9317313898251893), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9317482284306716), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9318116045007557), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9318729451350123), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9319441853889755), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9320122799693871), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9320466973388342), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9320539138840408), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9320833351837295), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9321449533774172), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9321646600970199), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9322124928389667), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9322641188931374), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9323075106841877), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ('valid_0', 'auc', np.float64(0.9323378571819798), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.932365798164703), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9324070620001155), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9324915325869575), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9325437137599902), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9325792413671615), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.932679532841572), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9327329167721392), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9328371865983944), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9328720665668933), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9330545156328873), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9331108601973854), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 12
# ('valid_0', 'auc', np.float64(0.9331363031452294), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9331610984544011), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9331988465370205), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9332724923060526), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9333337404204989), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# ('valid_0', 'auc', np.float64(0.9333908251434797), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9334449492325296), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9334828823547698), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9335036067922864), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# ('valid_0', 'auc', np.float64(0.9335487564597331), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9335781777594219), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9336011226723866), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 7
# ('valid_0', 'auc', np.float64(0.9336312841305581), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9336755085999014), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9337008590279351), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9337173275541759), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.933729540169141), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9337429555416406), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 8
# ('valid_0', 'auc', np.float64(0.9337573886320539), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9337805185846394), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9338515737989819), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 11
# ('valid_0', 'auc', np.float64(0.9338726683157398), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9338916348768599), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9339491821988924), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9339338239103757), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9339566763035301), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9339733298693916), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9339814716127017), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9339944243861495), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 10
# ('valid_0', 'auc', np.float64(0.9340091350359939), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9340291193150277), True)
# [LightGBM] [Debug] Trained a tree with leaves = 31 and depth = 9
# ('valid_0', 'auc', np.float64(0.9340531744657166), True)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 5
#       2 vlog_cb.vlog.log_start()
#       3 result = {}
# ----> 5 model = lgb.train(params, ds_train,
#       6         valid_sets=[ds_val],
#       7         # valid_names=['val'],
#       8         callbacks = [lgb.record_evaluation(result), vlog_cb]
#       9         )
#      11 vlog_cb.vlog.log_end()
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/lightgbm/engine.py:332, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, keep_training_booster, callbacks)
#     330 try:
#     331     for cb in callbacks_after_iter:
# --> 332         cb(
#     333             callback.CallbackEnv(
#     334                 model=booster,
#     335                 params=params,
#     336                 iteration=i,
#     337                 begin_iteration=init_iteration,
#     338                 end_iteration=init_iteration + num_boost_round,
#     339                 evaluation_result_list=evaluation_result_list,
#     340             )
#     341         )
#     342 except callback.EarlyStopException as earlyStopException:
#     343     booster.best_iteration = earlyStopException.best_iteration + 1
#
# File ~/Desktop/merlin/tools/callbacks.py:55, in VlogCallback.__call__(self, env)
#      53         res_stdv = item[4]
#      54         metrics[data_name+'_'+eval_name] = res_mean
# ---> 55 self.vlog.log_epoch(metrics)
#
# File ~/Desktop/merlin/tools/vlog.py:68, in VLog.log_epoch(self, info)
#      66     self.progress.update(dfhistory['epoch'].iloc[-1])
#      67     self.step, self.batchs = 0, self.step
# ---> 68 self.update_graph(title=title, x_bounds=x_bounds)
#
# File ~/Desktop/merlin/tools/vlog.py:187, in VLog.update_graph(self, title, x_bounds, y_bounds)
#     185 if self.in_jupyter:
#     186     self.graph_out.update(self.graph_ax.figure)
# --> 187 self.graph_fig.savefig(self.save_path)
#     188 self.plt.close()
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:481, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     434 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     435     """
#     436     Write the figure to a PNG file.
#     437
#    (...)    479         *metadata*, including the default 'Software' key.
#     480     """
# --> 481     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:429, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     424 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     425     """
#     426     Draw the canvas, then save it using `.image.imsave` (to which
#     427     *pil_kwargs* and *metadata* are forwarded).
#     428     """
# --> 429     FigureCanvasAgg.draw(self)
#     430     mpl.image.imsave(
#     431         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     432         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/figure.py:3257, in Figure.draw(self, renderer)
#    3254             # ValueError can occur when resizing a window.
#    3256     self.patch.draw(renderer)
# -> 3257     mimage._draw_list_compositing_images(
#    3258         renderer, self, artists, self.suppressComposite)
#    3260     renderer.close_group('figure')
#    3261 finally:
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/axes/_base.py:3181, in _AxesBase.draw(self, renderer)
#    3178 if artists_rasterized:
#    3179     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3181 mimage._draw_list_compositing_images(
#    3182     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3184 renderer.close_group('axes')
#    3185 self.stale = False
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/axis.py:1422, in Axis.draw(self, renderer)
#    1419     tick.draw(renderer)
#    1421 # Shift label away from axes to avoid overlapping ticklabels.
# -> 1422 self._update_label_position(renderer)
#    1423 self.label.draw(renderer)
#    1425 self._update_offset_text_position(tlb1, tlb2)
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/axis.py:2459, in XAxis._update_label_position(self, renderer)
#    2455     return
#    2457 # get bounding boxes for this axis and any siblings
#    2458 # that have been set by `fig.align_xlabels()`
# -> 2459 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2460 x, y = self.label.get_position()
#    2462 if self.label_position == 'bottom':
#    2463     # Union with extents of the bottom spine if present, of the axes otherwise.
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/axis.py:2252, in Axis._get_tick_boxes_siblings(self, renderer)
#    2250 axis = ax._axis_map[name]
#    2251 ticks_to_draw = axis._update_ticks()
# -> 2252 tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2253 bboxes.extend(tlb)
#    2254 bboxes2.extend(tlb2)
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/axis.py:1343, in Axis._get_ticklabel_bboxes(self, ticks, renderer)
#    1341 if renderer is None:
#    1342     renderer = self.get_figure(root=True)._get_renderer()
# -> 1343 return ([tick.label1.get_window_extent(renderer)
#    1344          for tick in ticks if tick.label1.get_visible()],
#    1345         [tick.label2.get_window_extent(renderer)
#    1346          for tick in ticks if tick.label2.get_visible()])
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/text.py:970, in Text.get_window_extent(self, renderer, dpi)
#     968 with cbook._setattr_cm(fig, dpi=dpi):
#     969     bbox, info, descent = self._get_layout(self._renderer)
# --> 970     x, y = self.get_unitless_position()
#     971     x, y = self.get_transform().transform((x, y))
#     972     bbox = bbox.translated(x, y)
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/text.py:906, in Text.get_unitless_position(self)
#     903 # This will get the position with all unit information stripped away.
#     904 # This is here for convenience since it is done in several locations.
#     905 x = float(self.convert_xunits(self._x))
# --> 906 y = float(self.convert_yunits(self._y))
#     907 return x, y
#
# File /opt/anaconda3/envs/howl/lib/python3.12/site-packages/matplotlib/artist.py:287, in Artist.convert_yunits(self, y)
#     280 def convert_yunits(self, y):
#     281     """
#     282     Convert *y* using the unit type of the yaxis.
#     283
#     284     If the artist is not contained in an Axes or if the yaxis does not
#     285     have units, *y* itself is returned.
#     286     """
# --> 287     ax = getattr(self, 'axes', None)
#     288     if ax is None or ax.yaxis is None:
#     289         return y
#
# KeyboardInterrupt:

# %%
vlog_cb = callback(model.n_trials, monitor_metric="val_auc", monitor_mode="max")
vlog_cb.vlog.log_start()

model = model.fit(
    ds_train,
    valid_sets=[ds_val],
    valid_names=["val"],
    callbacks = [model.record_evaluation(result), vlog_cb]
)

vlog_cb.vlog.log_end()

# %% [markdown]
# # 模型评估

# %%
from sklearn.metrics import roc_auc_score 
y_pred_val = model.predict(dfval[num_cols+cat_cols], num_iteration=model.best_iteration)
val_auc = roc_auc_score(dfval[target_col],y_pred_val) 

y_pred_test = model.predict(dftest[num_cols+cat_cols], num_iteration=model.best_iteration)
test_auc = roc_auc_score(dftest[target_col],y_pred_test) 

print('val_auc = ',val_auc)
print('test_auc = ' , test_auc)

# %% [markdown]
# # 模型部署

# %%
#预测概率
y_test = model.predict(dftest[num_cols+cat_cols], num_iteration=model.best_iteration)

#获取样本在每棵树上叶子结点的索引，可以把它们作为onehot特征喂入线性模型
y_test_leaf = model.predict(dftest[num_cols+cat_cols], pred_leaf=True, num_iteration=model.best_iteration)

# %%
y_test_leaf

# %% [markdown]
# # 模型保存

# %%
model.save_model("model.txt")
model_loaded = lgb.Booster(model_file='model.txt')
ypred_test = model_loaded.predict(dftest[num_cols+cat_cols], num_iteration=model_loaded.best_iteration)
